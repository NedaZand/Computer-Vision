# %%
# Codes from Computer Vision Class
# Professor Desai

# %%
#!pip install plotly
#change
#!pip install skimage
#this line gave me an error "ERROR: No matching distribution found for skimage" so I installed 
#!pip install scikit-image
import cv2
import pandas as pa
import matplotlib.pylab as plt
import numpy as np
import plotly.graph_objects as go 
from skimage import data

# %%
plt.rcParams.update({'text.color' : "white",
                     'axes.labelcolor' : "white",
                     'xtick.color' : "white",
                     'ytick.color' : "white"})

# %%
#read the image
img = cv2.imread('./myImage.jpg')
#conver image in RGB mode
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#print the 3D matrix of the image
#print(img)
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#print the image in the red channel
img[:,:,1] = 0
img[:,:,2] = 0
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#print the blue channel
#the previous img has been chaned so load it again
img = cv2.imread('./myImage.jpg')
#conver image in RGB mode
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[:,:,0] = 0
img[:,:,1] = 0
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#print the green channel
#the previous img has chaned so load it again
img = cv2.imread('./myImage.jpg')
#conver image in RGB mode
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[:,:,0] = 0
img[:,:,2] = 0
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
# the border
#there is a white frame around the image
#how to individualy get the channels
img = cv2.imread('./rgb.png')
#conver image in RGB mode
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
#the original image
plt.axis('off')
# Out:
# (-0.5, 607.5, 213.5, -0.5)

# %%
img[:,:,0] = 0
img[:,:,1] = 0
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 607.5, 213.5, -0.5)

# %%
#how to extract red blue and green channels of an image?
img = cv2.imread('./myImage.jpg')
r,g,b = cv2.split(img)
plt.imshow(r, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
plt.imshow(g, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
plt.imshow(b, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#extracting image r g b colors from hsv format
img = cv2.imread('./myImage.jpg')
plt.imshow(img)
img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
r,g,b = cv2.split(img)
#should see the original image here
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#show the Hue value
plt.imshow(r, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#show the saturation value
plt.imshow(g, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)

# %%
#show the value
plt.imshow(b, cmap = 'gray')
#print(r)
plt.axis('off')
# Out:
# (-0.5, 4031.5, 3023.5, -0.5)
